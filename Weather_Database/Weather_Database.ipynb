# %%
# Dependencies 
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import random
from citipy import citipy
from datetime import datetime 
from config import weather_api_key
import requests
import time
from scipy.stats import linregress
import gmaps
from config import g_key

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 767

# %%
# Create an empty list to hold the weather data.
city_data = []
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Date": city_date,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc,
                         })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | puerto ayora
# Processing Record 2 of Set 1 | qaanaaq
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | jamestown
# Processing Record 5 of Set 1 | waingapu
# Processing Record 6 of Set 1 | iqaluit
# Processing Record 7 of Set 1 | leningradskiy
# Processing Record 8 of Set 1 | bluff
# Processing Record 9 of Set 1 | tulum
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | barrow
# Processing Record 12 of Set 1 | thompson
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | atar
# Processing Record 15 of Set 1 | pokhara
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | tabuk
# Processing Record 18 of Set 1 | bengkulu
# Processing Record 19 of Set 1 | fare
# Processing Record 20 of Set 1 | flinders
# Processing Record 21 of Set 1 | mar del plata
# Processing Record 22 of Set 1 | hithadhoo
# Processing Record 23 of Set 1 | gushi
# Processing Record 24 of Set 1 | yellowknife
# Processing Record 25 of Set 1 | mahanoro
# Processing Record 26 of Set 1 | cabo san lucas
# Processing Record 27 of Set 1 | tasiilaq
# Processing Record 28 of Set 1 | narsaq
# Processing Record 29 of Set 1 | ilulissat
# Processing Record 30 of Set 1 | wismar
# Processing Record 31 of Set 1 | estelle
# Processing Record 32 of Set 1 | okhotsk
# Processing Record 33 of Set 1 | beringovskiy
# Processing Record 34 of Set 1 | nioro
# Processing Record 35 of Set 1 | pevek
# Processing Record 36 of Set 1 | kapaa
# Processing Record 37 of Set 1 | albany
# Processing Record 38 of Set 1 | lata
# Processing Record 39 of Set 1 | bethel
# Processing Record 40 of Set 1 | yulara
# Processing Record 41 of Set 1 | lavrentiya
# Processing Record 42 of Set 1 | carnarvon
# Processing Record 43 of Set 1 | atuona
# Processing Record 44 of Set 1 | homer
# Processing Record 45 of Set 1 | xingcheng
# Processing Record 46 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 47 of Set 1 | vaini
# Processing Record 48 of Set 1 | kaitangata
# Processing Record 49 of Set 1 | mount isa
# Processing Record 50 of Set 1 | nikolskoye
# Processing Record 1 of Set 2 | lake charles
# Processing Record 2 of Set 2 | bull savanna
# Processing Record 3 of Set 2 | san patricio
# Processing Record 4 of Set 2 | longyearbyen
# Processing Record 5 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 2 | votkinsk
# Processing Record 7 of Set 2 | saldanha
# Processing Record 8 of Set 2 | mahebourg
# Processing Record 9 of Set 2 | provideniya
# Processing Record 10 of Set 2 | tuktoyaktuk
# Processing Record 11 of Set 2 | orel-izumrud
# Processing Record 12 of Set 2 | hobart
# Processing Record 13 of Set 2 | huilong
# Processing Record 14 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 2 | karratha
# Processing Record 16 of Set 2 | atasu
# Processing Record 17 of Set 2 | naze
# Processing Record 18 of Set 2 | zyryanka
# Processing Record 19 of Set 2 | karpogory
# Processing Record 20 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 2 | shangrao
# Processing Record 22 of Set 2 | kodiak
# Processing Record 23 of Set 2 | usinsk
# Processing Record 24 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 25 of Set 2 | glens falls
# Processing Record 26 of Set 2 | esperance
# Processing Record 27 of Set 2 | toowoomba
# Processing Record 28 of Set 2 | livingston
# Processing Record 29 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 2 | praia da vitoria
# Processing Record 31 of Set 2 | katsuura
# Processing Record 32 of Set 2 | busselton
# Processing Record 33 of Set 2 | ziro
# Processing Record 34 of Set 2 | dzilam gonzalez
# Processing Record 35 of Set 2 | rioja
# Processing Record 36 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 2 | thinadhoo
# Processing Record 38 of Set 2 | mundra
# Processing Record 39 of Set 2 | havoysund
# Processing Record 40 of Set 2 | ubinskoye
# Processing Record 41 of Set 2 | rameswaram
# Processing Record 42 of Set 2 | pisco
# Processing Record 43 of Set 2 | floro
# Processing Record 44 of Set 2 | victoria
# Processing Record 45 of Set 2 | shihezi
# Processing Record 46 of Set 2 | dalvik
# Processing Record 47 of Set 2 | klaksvik
# Processing Record 48 of Set 2 | matay
# Processing Record 49 of Set 2 | te anau
# Processing Record 50 of Set 2 | upernavik
# Processing Record 1 of Set 3 | bredasdorp
# Processing Record 2 of Set 3 | vila velha
# Processing Record 3 of Set 3 | tveit
# Processing Record 4 of Set 3 | chokurdakh
# Processing Record 5 of Set 3 | west fargo
# Processing Record 6 of Set 3 | lebu
# Processing Record 7 of Set 3 | new norfolk
# Processing Record 8 of Set 3 | svetlogorsk
# Processing Record 9 of Set 3 | faanui
# Processing Record 10 of Set 3 | nerchinskiy zavod
# Processing Record 11 of Set 3 | ambilobe
# Processing Record 12 of Set 3 | saint-philippe
# Processing Record 13 of Set 3 | vostok
# Processing Record 14 of Set 3 | avarua
# Processing Record 15 of Set 3 | massaguet
# Processing Record 16 of Set 3 | ankazoabo
# Processing Record 17 of Set 3 | matagami
# Processing Record 18 of Set 3 | malwan
# City not found. Skipping...
# Processing Record 19 of Set 3 | ilesha
# Processing Record 20 of Set 3 | port alfred
# Processing Record 21 of Set 3 | vestmannaeyjar
# Processing Record 22 of Set 3 | polunochnoye
# Processing Record 23 of Set 3 | saint george
# Processing Record 24 of Set 3 | castro
# Processing Record 25 of Set 3 | hofn
# Processing Record 26 of Set 3 | vanimo
# Processing Record 27 of Set 3 | ndola
# Processing Record 28 of Set 3 | torbay
# Processing Record 29 of Set 3 | hermanus
# Processing Record 30 of Set 3 | hasaki
# Processing Record 31 of Set 3 | omboue
# Processing Record 32 of Set 3 | ust-nera
# Processing Record 33 of Set 3 | sobolevo
# Processing Record 34 of Set 3 | tangping
# Processing Record 35 of Set 3 | port elizabeth
# Processing Record 36 of Set 3 | butaritari
# Processing Record 37 of Set 3 | saint anthony
# Processing Record 38 of Set 3 | fukuyama
# Processing Record 39 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 40 of Set 3 | orlik
# Processing Record 41 of Set 3 | porto novo
# Processing Record 42 of Set 3 | luderitz
# Processing Record 43 of Set 3 | chumikan
# Processing Record 44 of Set 3 | waipawa
# Processing Record 45 of Set 3 | khatanga
# Processing Record 46 of Set 3 | katherine
# Processing Record 47 of Set 3 | moranbah
# Processing Record 48 of Set 3 | tema
# Processing Record 49 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 50 of Set 3 | vavuniya
# Processing Record 1 of Set 4 | port blair
# Processing Record 2 of Set 4 | namibe
# Processing Record 3 of Set 4 | ponta do sol
# Processing Record 4 of Set 4 | vrapciste
# Processing Record 5 of Set 4 | sibolga
# Processing Record 6 of Set 4 | kysyl-syr
# Processing Record 7 of Set 4 | kourou
# Processing Record 8 of Set 4 | kruisfontein
# Processing Record 9 of Set 4 | fortuna
# Processing Record 10 of Set 4 | bakchar
# Processing Record 11 of Set 4 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 12 of Set 4 | chinhoyi
# Processing Record 13 of Set 4 | scottsburgh
# City not found. Skipping...
# Processing Record 14 of Set 4 | aklavik
# Processing Record 15 of Set 4 | pangnirtung
# Processing Record 16 of Set 4 | faya
# Processing Record 17 of Set 4 | cape town
# Processing Record 18 of Set 4 | mergui
# City not found. Skipping...
# Processing Record 19 of Set 4 | beni
# Processing Record 20 of Set 4 | yanam
# Processing Record 21 of Set 4 | paamiut
# Processing Record 22 of Set 4 | sao jose da coroa grande
# Processing Record 23 of Set 4 | cusco
# Processing Record 24 of Set 4 | broken hill
# Processing Record 25 of Set 4 | bereda
# Processing Record 26 of Set 4 | morales
# Processing Record 27 of Set 4 | gemena
# Processing Record 28 of Set 4 | oyama
# Processing Record 29 of Set 4 | shieli
# Processing Record 30 of Set 4 | cherskiy
# Processing Record 31 of Set 4 | dingle
# Processing Record 32 of Set 4 | la rioja
# Processing Record 33 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 34 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 35 of Set 4 | daxian
# City not found. Skipping...
# Processing Record 36 of Set 4 | zemio
# Processing Record 37 of Set 4 | deputatskiy
# Processing Record 38 of Set 4 | belmonte
# Processing Record 39 of Set 4 | hilo
# Processing Record 40 of Set 4 | arraial do cabo
# Processing Record 41 of Set 4 | codrington
# Processing Record 42 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 43 of Set 4 | haines junction
# Processing Record 44 of Set 4 | kisangani
# Processing Record 45 of Set 4 | komsomolskiy
# Processing Record 46 of Set 4 | snezhnogorsk
# Processing Record 47 of Set 4 | nantucket
# Processing Record 48 of Set 4 | den helder
# Processing Record 49 of Set 4 | kalmunai
# Processing Record 50 of Set 4 | los llanos de aridane
# Processing Record 1 of Set 5 | isangel
# Processing Record 2 of Set 5 | pouembout
# Processing Record 3 of Set 5 | vilcun
# Processing Record 4 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 5 of Set 5 | acari
# Processing Record 6 of Set 5 | jalu
# Processing Record 7 of Set 5 | fukue
# Processing Record 8 of Set 5 | rio grande
# Processing Record 9 of Set 5 | rawson
# Processing Record 10 of Set 5 | shakawe
# Processing Record 11 of Set 5 | san ignacio
# Processing Record 12 of Set 5 | itarema
# Processing Record 13 of Set 5 | clyde river
# Processing Record 14 of Set 5 | bur gabo
# City not found. Skipping...
# Processing Record 15 of Set 5 | makaha
# Processing Record 16 of Set 5 | verkhoyansk
# Processing Record 17 of Set 5 | dikson
# Processing Record 18 of Set 5 | teya
# Processing Record 19 of Set 5 | kletskaya
# Processing Record 20 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 21 of Set 5 | urubicha
# Processing Record 22 of Set 5 | manta
# Processing Record 23 of Set 5 | saskylakh
# Processing Record 24 of Set 5 | mackay
# Processing Record 25 of Set 5 | port hawkesbury
# Processing Record 26 of Set 5 | lompoc
# Processing Record 27 of Set 5 | cabedelo
# Processing Record 28 of Set 5 | maniitsoq
# Processing Record 29 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 30 of Set 5 | dronten
# Processing Record 31 of Set 5 | bandarbeyla
# Processing Record 32 of Set 5 | kavieng
# Processing Record 33 of Set 5 | sinnamary
# Processing Record 34 of Set 5 | kendari
# Processing Record 35 of Set 5 | namatanai
# Processing Record 36 of Set 5 | souillac
# Processing Record 37 of Set 5 | severo-kurilsk
# Processing Record 38 of Set 5 | dunedin
# Processing Record 39 of Set 5 | berlevag
# Processing Record 40 of Set 5 | coihueco
# Processing Record 41 of Set 5 | tuatapere
# Processing Record 42 of Set 5 | lahaina
# Processing Record 43 of Set 5 | ahipara
# Processing Record 44 of Set 5 | comodoro rivadavia
# Processing Record 45 of Set 5 | roald
# Processing Record 46 of Set 5 | sijunjung
# Processing Record 47 of Set 5 | paramonga
# Processing Record 48 of Set 5 | akdepe
# Processing Record 49 of Set 5 | ostrovnoy
# Processing Record 50 of Set 5 | porangatu
# Processing Record 1 of Set 6 | bolshaya martynovka
# Processing Record 2 of Set 6 | buala
# Processing Record 3 of Set 6 | ucluelet
# Processing Record 4 of Set 6 | malanville
# Processing Record 5 of Set 6 | coracora
# Processing Record 6 of Set 6 | ambulu
# Processing Record 7 of Set 6 | hambantota
# Processing Record 8 of Set 6 | nicoya
# Processing Record 9 of Set 6 | ukiah
# Processing Record 10 of Set 6 | olafsvik
# Processing Record 11 of Set 6 | viligili
# City not found. Skipping...
# Processing Record 12 of Set 6 | norman wells
# Processing Record 13 of Set 6 | kribi
# Processing Record 14 of Set 6 | gairo
# Processing Record 15 of Set 6 | soyo
# Processing Record 16 of Set 6 | urumqi
# Processing Record 17 of Set 6 | partizansk
# Processing Record 18 of Set 6 | lexington
# Processing Record 19 of Set 6 | tautira
# Processing Record 20 of Set 6 | cidreira
# Processing Record 21 of Set 6 | gubkinskiy
# Processing Record 22 of Set 6 | teknaf
# Processing Record 23 of Set 6 | lovozero
# Processing Record 24 of Set 6 | avenal
# Processing Record 25 of Set 6 | tecpan
# Processing Record 26 of Set 6 | constitucion
# Processing Record 27 of Set 6 | puerto leguizamo
# Processing Record 28 of Set 6 | bogande
# Processing Record 29 of Set 6 | lasa
# Processing Record 30 of Set 6 | ribeira grande
# Processing Record 31 of Set 6 | moindou
# Processing Record 32 of Set 6 | abu samrah
# Processing Record 33 of Set 6 | adrar
# Processing Record 34 of Set 6 | port hardy
# Processing Record 35 of Set 6 | port said
# Processing Record 36 of Set 6 | east london
# Processing Record 37 of Set 6 | baherden
# Processing Record 38 of Set 6 | nyurba
# Processing Record 39 of Set 6 | port lincoln
# Processing Record 40 of Set 6 | cazaje
# City not found. Skipping...
# Processing Record 41 of Set 6 | abu dhabi
# Processing Record 42 of Set 6 | qandala
# Processing Record 43 of Set 6 | greven
# Processing Record 44 of Set 6 | guaruja
# Processing Record 45 of Set 6 | westport
# Processing Record 46 of Set 6 | airai
# Processing Record 47 of Set 6 | dubbo
# Processing Record 48 of Set 6 | saint-augustin
# Processing Record 49 of Set 6 | dukat
# Processing Record 50 of Set 6 | banjar
# Processing Record 1 of Set 7 | medvedevo
# Processing Record 2 of Set 7 | vao
# Processing Record 3 of Set 7 | maryville
# Processing Record 4 of Set 7 | ludvika
# Processing Record 5 of Set 7 | katha
# City not found. Skipping...
# Processing Record 6 of Set 7 | inirida
# Processing Record 7 of Set 7 | bambous virieux
# Processing Record 8 of Set 7 | umm durman
# City not found. Skipping...
# Processing Record 9 of Set 7 | fairbanks
# Processing Record 10 of Set 7 | sitka
# Processing Record 11 of Set 7 | kutum
# Processing Record 12 of Set 7 | chernyshevskiy
# Processing Record 13 of Set 7 | mapiripan
# Processing Record 14 of Set 7 | hudson bay
# Processing Record 15 of Set 7 | the valley
# Processing Record 16 of Set 7 | galiwinku
# City not found. Skipping...
# Processing Record 17 of Set 7 | larap
# Processing Record 18 of Set 7 | pangoa
# Processing Record 19 of Set 7 | husavik
# Processing Record 20 of Set 7 | cervo
# Processing Record 21 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 22 of Set 7 | alyangula
# Processing Record 23 of Set 7 | mayumba
# Processing Record 24 of Set 7 | abeche
# Processing Record 25 of Set 7 | kharabali
# Processing Record 26 of Set 7 | corn island
# Processing Record 27 of Set 7 | kungsbacka
# Processing Record 28 of Set 7 | talnakh
# Processing Record 29 of Set 7 | asau
# Processing Record 30 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 31 of Set 7 | zheleznodorozhnyy
# Processing Record 32 of Set 7 | yumen
# Processing Record 33 of Set 7 | rio gallegos
# Processing Record 34 of Set 7 | college
# Processing Record 35 of Set 7 | varkaus
# Processing Record 36 of Set 7 | bambanglipuro
# Processing Record 37 of Set 7 | shelbyville
# Processing Record 38 of Set 7 | gosainganj
# Processing Record 39 of Set 7 | aden
# Processing Record 40 of Set 7 | omsukchan
# Processing Record 41 of Set 7 | oyon
# Processing Record 42 of Set 7 | moss point
# Processing Record 43 of Set 7 | hokitika
# Processing Record 44 of Set 7 | ubatuba
# Processing Record 45 of Set 7 | qinhuangdao
# Processing Record 46 of Set 7 | itupiranga
# Processing Record 47 of Set 7 | nago
# Processing Record 48 of Set 7 | tiksi
# Processing Record 49 of Set 7 | poum
# Processing Record 50 of Set 7 | midland
# Processing Record 1 of Set 8 | praia
# Processing Record 2 of Set 8 | skjervoy
# Processing Record 3 of Set 8 | georgetown
# Processing Record 4 of Set 8 | ust-kut
# Processing Record 5 of Set 8 | solnechnyy
# Processing Record 6 of Set 8 | koboko
# Processing Record 7 of Set 8 | puerto maldonado
# Processing Record 8 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 9 of Set 8 | hailar
# Processing Record 10 of Set 8 | mackenzie
# Processing Record 11 of Set 8 | igarka
# Processing Record 12 of Set 8 | amuntai
# Processing Record 13 of Set 8 | urucara
# Processing Record 14 of Set 8 | taltal
# Processing Record 15 of Set 8 | yuza
# Processing Record 16 of Set 8 | llangefni
# Processing Record 17 of Set 8 | francisco sa
# Processing Record 18 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 19 of Set 8 | bilibino
# Processing Record 20 of Set 8 | kabanjahe
# Processing Record 21 of Set 8 | webuye
# Processing Record 22 of Set 8 | sergeyevka
# Processing Record 23 of Set 8 | san cristobal
# Processing Record 24 of Set 8 | vardo
# Processing Record 25 of Set 8 | progreso
# Processing Record 26 of Set 8 | limbang
# Processing Record 27 of Set 8 | farafangana
# Processing Record 28 of Set 8 | sulangan
# Processing Record 29 of Set 8 | lodja
# Processing Record 30 of Set 8 | harare
# Processing Record 31 of Set 8 | leshukonskoye
# Processing Record 32 of Set 8 | bodden town
# Processing Record 33 of Set 8 | silifke
# Processing Record 34 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 35 of Set 8 | walvis bay
# Processing Record 36 of Set 8 | basoko
# Processing Record 37 of Set 8 | batemans bay
# Processing Record 38 of Set 8 | mananjary
# Processing Record 39 of Set 8 | troitsko-pechorsk
# Processing Record 40 of Set 8 | roma
# Processing Record 41 of Set 8 | houston
# Processing Record 42 of Set 8 | khormuj
# City not found. Skipping...
# Processing Record 43 of Set 8 | jiuquan
# Processing Record 44 of Set 8 | mawlaik
# Processing Record 45 of Set 8 | tombouctou
# Processing Record 46 of Set 8 | okato
# Processing Record 47 of Set 8 | cortez
# Processing Record 48 of Set 8 | margate
# Processing Record 49 of Set 8 | san vicente
# Processing Record 50 of Set 8 | wulanhaote
# City not found. Skipping...
# Processing Record 1 of Set 9 | ixtapa
# Processing Record 2 of Set 9 | necochea
# Processing Record 3 of Set 9 | general jose eduvigis diaz
# Processing Record 4 of Set 9 | jatiroto
# Processing Record 5 of Set 9 | whitehorse
# Processing Record 6 of Set 9 | oriximina
# Processing Record 7 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 8 of Set 9 | riyadh
# Processing Record 9 of Set 9 | ondjiva
# Processing Record 10 of Set 9 | goderich
# Processing Record 11 of Set 9 | quesnel
# Processing Record 12 of Set 9 | half moon bay
# Processing Record 13 of Set 9 | stornoway
# Processing Record 14 of Set 9 | preobrazheniye
# Processing Record 15 of Set 9 | verkhnevilyuysk
# Processing Record 16 of Set 9 | kavaratti
# Processing Record 17 of Set 9 | brae
# Processing Record 18 of Set 9 | sotouboua
# Processing Record 19 of Set 9 | eyl
# Processing Record 20 of Set 9 | sibu
# Processing Record 21 of Set 9 | long beach
# Processing Record 22 of Set 9 | topalu
# Processing Record 23 of Set 9 | port-gentil
# Processing Record 24 of Set 9 | luwuk
# Processing Record 25 of Set 9 | port macquarie
# Processing Record 26 of Set 9 | saint-francois
# Processing Record 27 of Set 9 | la ronge
# Processing Record 28 of Set 9 | coihaique
# Processing Record 29 of Set 9 | vagur
# Processing Record 30 of Set 9 | pajapan
# Processing Record 31 of Set 9 | pakenham
# Processing Record 32 of Set 9 | pampas
# Processing Record 33 of Set 9 | kahului
# Processing Record 34 of Set 9 | ginir
# Processing Record 35 of Set 9 | malanje
# Processing Record 36 of Set 9 | ancud
# Processing Record 37 of Set 9 | sao filipe
# Processing Record 38 of Set 9 | lamu
# Processing Record 39 of Set 9 | harnosand
# Processing Record 40 of Set 9 | marawi
# Processing Record 41 of Set 9 | sola
# Processing Record 42 of Set 9 | lorengau
# Processing Record 43 of Set 9 | dongning
# Processing Record 44 of Set 9 | chuy
# Processing Record 45 of Set 9 | dax
# Processing Record 46 of Set 9 | aswan
# Processing Record 47 of Set 9 | bubaque
# Processing Record 48 of Set 9 | lulea
# Processing Record 49 of Set 9 | lagoa
# Processing Record 50 of Set 9 | ocampo
# Processing Record 1 of Set 10 | yeppoon
# Processing Record 2 of Set 10 | smithers
# Processing Record 3 of Set 10 | tura
# Processing Record 4 of Set 10 | salalah
# Processing Record 5 of Set 10 | kargil
# Processing Record 6 of Set 10 | takoradi
# Processing Record 7 of Set 10 | west bay
# Processing Record 8 of Set 10 | kentau
# Processing Record 9 of Set 10 | saint-joseph
# Processing Record 10 of Set 10 | olavarria
# Processing Record 11 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 12 of Set 10 | guerrero negro
# Processing Record 13 of Set 10 | challapalle
# Processing Record 14 of Set 10 | yerbogachen
# Processing Record 15 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 16 of Set 10 | minden
# Processing Record 17 of Set 10 | barabai
# Processing Record 18 of Set 10 | ust-maya
# Processing Record 19 of Set 10 | katangli
# Processing Record 20 of Set 10 | sisimiut
# Processing Record 21 of Set 10 | trojes
# Processing Record 22 of Set 10 | voh
# Processing Record 23 of Set 10 | srandakan
# Processing Record 24 of Set 10 | kupang
# Processing Record 25 of Set 10 | grenada
# Processing Record 26 of Set 10 | falealupo
# City not found. Skipping...
# Processing Record 27 of Set 10 | bulihan
# Processing Record 28 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 29 of Set 10 | hamilton
# Processing Record 30 of Set 10 | bairiki
# Processing Record 31 of Set 10 | mpongwe
# Processing Record 32 of Set 10 | havre-saint-pierre
# Processing Record 33 of Set 10 | dandong
# Processing Record 34 of Set 10 | guymon
# Processing Record 35 of Set 10 | ondorhaan
# City not found. Skipping...
# Processing Record 36 of Set 10 | axim
# Processing Record 37 of Set 10 | hobyo
# Processing Record 38 of Set 10 | formoso do araguaia
# City not found. Skipping...
# Processing Record 39 of Set 10 | tiznit
# Processing Record 40 of Set 10 | svetlyy
# Processing Record 41 of Set 10 | camacha
# Processing Record 42 of Set 10 | amapa
# Processing Record 43 of Set 10 | redmond
# Processing Record 44 of Set 10 | bilma
# Processing Record 45 of Set 10 | dok kham tai
# Processing Record 46 of Set 10 | hami
# Processing Record 47 of Set 10 | buin
# Processing Record 48 of Set 10 | arcata
# Processing Record 49 of Set 10 | sao gabriel da cachoeira
# Processing Record 50 of Set 10 | beidao
# Processing Record 1 of Set 11 | jaguaribe
# Processing Record 2 of Set 11 | taoudenni
# Processing Record 3 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 4 of Set 11 | kamenka
# Processing Record 5 of Set 11 | quepos
# Processing Record 6 of Set 11 | andenes
# Processing Record 7 of Set 11 | nelson bay
# Processing Record 8 of Set 11 | ayan
# Processing Record 9 of Set 11 | pochutla
# Processing Record 10 of Set 11 | kununurra
# Processing Record 11 of Set 11 | artigas
# Processing Record 12 of Set 11 | grindavik
# Processing Record 13 of Set 11 | babu
# Processing Record 14 of Set 11 | mabaruma
# Processing Record 15 of Set 11 | thunder bay
# Processing Record 16 of Set 11 | tezu
# Processing Record 17 of Set 11 | carman
# Processing Record 18 of Set 11 | taksimo
# Processing Record 19 of Set 11 | kudahuvadhoo
# Processing Record 20 of Set 11 | kimbe
# Processing Record 21 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 22 of Set 11 | cockburn town
# Processing Record 23 of Set 11 | kieta
# Processing Record 24 of Set 11 | kunming
# Processing Record 25 of Set 11 | nanortalik
# Processing Record 26 of Set 11 | muravlenko
# Processing Record 27 of Set 11 | tunduru
# City not found. Skipping...
# Processing Record 28 of Set 11 | sao raimundo nonato
# Processing Record 29 of Set 11 | puerto rico
# Processing Record 30 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 31 of Set 11 | aquiraz
# Processing Record 32 of Set 11 | yarkovo
# Processing Record 33 of Set 11 | angelholm
# City not found. Skipping...
# Processing Record 34 of Set 11 | mumford
# Processing Record 35 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 36 of Set 11 | weymouth
# Processing Record 37 of Set 11 | suure-jaani
# Processing Record 38 of Set 11 | bitam
# Processing Record 39 of Set 11 | aykhal
# Processing Record 40 of Set 11 | filingue
# Processing Record 41 of Set 11 | shache
# Processing Record 42 of Set 11 | jumla
# Processing Record 43 of Set 11 | sao felix do xingu
# Processing Record 44 of Set 11 | huarmey
# Processing Record 45 of Set 11 | huanren
# Processing Record 46 of Set 11 | maningrida
# Processing Record 47 of Set 11 | mayo
# Processing Record 48 of Set 11 | touros
# Processing Record 49 of Set 11 | ponta delgada
# Processing Record 50 of Set 11 | brejo da madre de deus
# Processing Record 1 of Set 12 | sembe
# Processing Record 2 of Set 12 | altay
# Processing Record 3 of Set 12 | jishou
# Processing Record 4 of Set 12 | hunza
# City not found. Skipping...
# Processing Record 5 of Set 12 | khuzdar
# Processing Record 6 of Set 12 | aguadilla
# Processing Record 7 of Set 12 | neiafu
# Processing Record 8 of Set 12 | umm kaddadah
# Processing Record 9 of Set 12 | trincomalee
# Processing Record 10 of Set 12 | schwabisch hall
# Processing Record 11 of Set 12 | kholodnyy
# Processing Record 12 of Set 12 | nuuk
# Processing Record 13 of Set 12 | nome
# Processing Record 14 of Set 12 | viedma
# Processing Record 15 of Set 12 | minas
# Processing Record 16 of Set 12 | forestville
# Processing Record 17 of Set 12 | perth
# Processing Record 18 of Set 12 | voznesenye
# Processing Record 19 of Set 12 | raymond terrace
# Processing Record 20 of Set 12 | steubenville
# Processing Record 21 of Set 12 | seymchan
# Processing Record 22 of Set 12 | san luis
# Processing Record 23 of Set 12 | niquero
# Processing Record 24 of Set 12 | yanggu
# Processing Record 25 of Set 12 | novopokrovka
# Processing Record 26 of Set 12 | mnogovershinnyy
# Processing Record 27 of Set 12 | uva
# Processing Record 28 of Set 12 | qena
# Processing Record 29 of Set 12 | innisfail
# Processing Record 30 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 31 of Set 12 | sahrak
# City not found. Skipping...
# Processing Record 32 of Set 12 | palu
# Processing Record 33 of Set 12 | san francisco
# Processing Record 34 of Set 12 | avera
# Processing Record 35 of Set 12 | matoury
# Processing Record 36 of Set 12 | tortoli
# Processing Record 37 of Set 12 | pa daet
# Processing Record 38 of Set 12 | santander
# Processing Record 39 of Set 12 | dhidhdhoo
# Processing Record 40 of Set 12 | xiashi
# Processing Record 41 of Set 12 | ulladulla
# Processing Record 42 of Set 12 | shingu
# Processing Record 43 of Set 12 | hearst
# Processing Record 44 of Set 12 | okandja
# City not found. Skipping...
# Processing Record 45 of Set 12 | strandby
# Processing Record 46 of Set 12 | paciran
# Processing Record 47 of Set 12 | numan
# Processing Record 48 of Set 12 | de aar
# Processing Record 49 of Set 12 | princeton
# Processing Record 50 of Set 12 | moron
# Processing Record 1 of Set 13 | acarau
# Processing Record 2 of Set 13 | nishihara
# Processing Record 3 of Set 13 | batavia
# Processing Record 4 of Set 13 | geraldton
# Processing Record 5 of Set 13 | dzialdowo
# Processing Record 6 of Set 13 | kobojango
# City not found. Skipping...
# Processing Record 7 of Set 13 | zhigansk
# Processing Record 8 of Set 13 | santa maria
# Processing Record 9 of Set 13 | lima
# Processing Record 10 of Set 13 | peniche
# Processing Record 11 of Set 13 | shasta lake
# Processing Record 12 of Set 13 | koosa
# Processing Record 13 of Set 13 | port shepstone
# Processing Record 14 of Set 13 | hervey bay
# Processing Record 15 of Set 13 | belyy yar
# Processing Record 16 of Set 13 | staicele
# Processing Record 17 of Set 13 | rurrenabaque
# Processing Record 18 of Set 13 | kyzyl-suu
# Processing Record 19 of Set 13 | sinnar
# Processing Record 20 of Set 13 | jacqueville
# Processing Record 21 of Set 13 | aleksandrovka
# Processing Record 22 of Set 13 | sao joao da barra
# Processing Record 23 of Set 13 | alofi
# Processing Record 24 of Set 13 | adzope
# Processing Record 25 of Set 13 | saint-leu
# Processing Record 26 of Set 13 | mwinilunga
# Processing Record 27 of Set 13 | muros
# Processing Record 28 of Set 13 | jadu
# Processing Record 29 of Set 13 | aguilar de la frontera
# Processing Record 30 of Set 13 | obidos
# Processing Record 31 of Set 13 | hirara
# Processing Record 32 of Set 13 | sangar
# Processing Record 33 of Set 13 | rognan
# Processing Record 34 of Set 13 | pompeia
# Processing Record 35 of Set 13 | suchiate
# Processing Record 36 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 37 of Set 13 | bintulu
# Processing Record 38 of Set 13 | mae hong son
# Processing Record 39 of Set 13 | payson
# Processing Record 40 of Set 13 | antofagasta
# Processing Record 41 of Set 13 | camara de lobos
# Processing Record 42 of Set 13 | yakeshi
# Processing Record 43 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 44 of Set 13 | magadan
# Processing Record 45 of Set 13 | rocha
# Processing Record 46 of Set 13 | killybegs
# Processing Record 47 of Set 13 | haysville
# Processing Record 48 of Set 13 | balsas
# Processing Record 49 of Set 13 | caravelas
# Processing Record 50 of Set 13 | mao
# Processing Record 1 of Set 14 | port moresby
# Processing Record 2 of Set 14 | pointe michel
# Processing Record 3 of Set 14 | nabire
# Processing Record 4 of Set 14 | cayenne
# Processing Record 5 of Set 14 | deer lake
# Processing Record 6 of Set 14 | kangaatsiaq
# Processing Record 7 of Set 14 | mount gambier
# Processing Record 8 of Set 14 | yirol
# City not found. Skipping...
# Processing Record 9 of Set 14 | grakhovo
# Processing Record 10 of Set 14 | quelimane
# Processing Record 11 of Set 14 | sambava
# Processing Record 12 of Set 14 | rosario do sul
# Processing Record 13 of Set 14 | grand river south east
# City not found. Skipping...
# Processing Record 14 of Set 14 | ust-karsk
# Processing Record 15 of Set 14 | bressanone
# Processing Record 16 of Set 14 | vila franca do campo
# Processing Record 17 of Set 14 | san isidro
# Processing Record 18 of Set 14 | storslett
# Processing Record 19 of Set 14 | fasa
# Processing Record 20 of Set 14 | phonhong
# Processing Record 21 of Set 14 | auki
# Processing Record 22 of Set 14 | ferme-neuve
# Processing Record 23 of Set 14 | tres lagoas
# Processing Record 24 of Set 14 | laredo
# Processing Record 25 of Set 14 | sorland
# Processing Record 26 of Set 14 | richards bay
# Processing Record 27 of Set 14 | ranfurly
# Processing Record 28 of Set 14 | ruatoria
# City not found. Skipping...
# Processing Record 29 of Set 14 | sayyan
# Processing Record 30 of Set 14 | campo verde
# Processing Record 31 of Set 14 | tubruq
# City not found. Skipping...
# Processing Record 32 of Set 14 | chingirlau
# Processing Record 33 of Set 14 | sennoy
# Processing Record 34 of Set 14 | bani
# Processing Record 35 of Set 14 | hurricane
# Processing Record 36 of Set 14 | mehran
# Processing Record 37 of Set 14 | kazalinsk
# City not found. Skipping...
# Processing Record 38 of Set 14 | athabasca
# Processing Record 39 of Set 14 | ratnagiri
# Processing Record 40 of Set 14 | menongue
# Processing Record 41 of Set 14 | sydney
# Processing Record 42 of Set 14 | duncan
# Processing Record 43 of Set 14 | biak
# Processing Record 44 of Set 14 | mbini
# Processing Record 45 of Set 14 | dahra
# Processing Record 46 of Set 14 | astorga
# Processing Record 47 of Set 14 | mezen
# Processing Record 48 of Set 14 | maarianhamina
# Processing Record 49 of Set 14 | warah
# Processing Record 50 of Set 14 | garissa
# Processing Record 1 of Set 15 | new castle
# Processing Record 2 of Set 15 | pavda
# City not found. Skipping...
# Processing Record 3 of Set 15 | suntar
# Processing Record 4 of Set 15 | mahibadhoo
# Processing Record 5 of Set 15 | northam
# Processing Record 6 of Set 15 | beyneu
# Processing Record 7 of Set 15 | nieuw amsterdam
# Processing Record 8 of Set 15 | dalianwan
# Processing Record 9 of Set 15 | sana
# Processing Record 10 of Set 15 | lucea
# Processing Record 11 of Set 15 | phan thiet
# Processing Record 12 of Set 15 | shitanjing
# Processing Record 13 of Set 15 | malakal
# Processing Record 14 of Set 15 | luchegorsk
# Processing Record 15 of Set 15 | kirakira
# Processing Record 16 of Set 15 | panukulan
# Processing Record 17 of Set 15 | lota
# Processing Record 18 of Set 15 | ketchikan
# Processing Record 19 of Set 15 | aasiaat
# Processing Record 20 of Set 15 | saint-pierre
# Processing Record 21 of Set 15 | karangasem
# Processing Record 22 of Set 15 | grand gaube
# Processing Record 23 of Set 15 | dunmore east
# Processing Record 24 of Set 15 | corum
# Processing Record 25 of Set 15 | morro bay
# Processing Record 26 of Set 15 | port arthur
# Processing Record 27 of Set 15 | muyezerskiy
# Processing Record 28 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 29 of Set 15 | desaguadero
# Processing Record 30 of Set 15 | yazman
# Processing Record 31 of Set 15 | haibowan
# City not found. Skipping...
# Processing Record 32 of Set 15 | bowen
# Processing Record 33 of Set 15 | arlit
# Processing Record 34 of Set 15 | pokrovskoye
# Processing Record 35 of Set 15 | bathsheba
# Processing Record 36 of Set 15 | anapskaya
# Processing Record 37 of Set 15 | chabahar
# Processing Record 38 of Set 15 | darhan
# Processing Record 39 of Set 15 | mairana
# Processing Record 40 of Set 15 | deloraine
# Processing Record 41 of Set 15 | sao miguel do araguaia
# Processing Record 42 of Set 15 | oksfjord
# Processing Record 43 of Set 15 | kampot
# Processing Record 44 of Set 15 | krasnyye chetai
# Processing Record 45 of Set 15 | male
# Processing Record 46 of Set 15 | imbituba
# Processing Record 47 of Set 15 | ardakan
# Processing Record 48 of Set 15 | portland
# Processing Record 49 of Set 15 | madoc
# Processing Record 50 of Set 15 | abiy adi
# City not found. Skipping...
# Processing Record 1 of Set 16 | akot
# Processing Record 2 of Set 16 | mutare
# Processing Record 3 of Set 16 | kasama
# Processing Record 4 of Set 16 | barawe
# City not found. Skipping...
# Processing Record 5 of Set 16 | namtsy
# Processing Record 6 of Set 16 | poplar bluff
# Processing Record 7 of Set 16 | mizdah
# Processing Record 8 of Set 16 | neijiang
# Processing Record 9 of Set 16 | kandava
# Processing Record 10 of Set 16 | saryshagan
# City not found. Skipping...
# Processing Record 11 of Set 16 | sabang
# Processing Record 12 of Set 16 | vung tau
# Processing Record 13 of Set 16 | klichka
# Processing Record 14 of Set 16 | nanyamba
# Processing Record 15 of Set 16 | barletta
# Processing Record 16 of Set 16 | elena
# Processing Record 17 of Set 16 | mujiayingzi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
print(len(city_data))
# Out:
# 704

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country                 Date      Lat       Lng  Max Temp  \
# 0   Puerto Ayora      EC  2022-09-08 02:06:13  -0.7393  -90.3518     68.56
# 1        Qaanaaq      GL  2022-09-08 02:06:58  77.4840  -69.3632     28.89
# 2   Punta Arenas      CL  2022-09-08 02:06:01 -53.1500  -70.9167     35.71
# 3      Jamestown      US  2022-09-08 02:05:45  42.0970  -79.2353     65.17
# 4       Waingapu      ID  2022-09-08 02:15:49  -9.6567  120.2641     85.59
# 5        Iqaluit      CA  2022-09-08 02:12:35  63.7506  -68.5145     42.53
# 6  Leningradskiy      RU  2022-09-08 02:11:17  69.3833  178.4167     46.99
# 7          Bluff      NZ  2022-09-08 02:06:15 -46.6000  168.3333     50.81
# 8          Tulum      MX  2022-09-08 02:15:52  20.2167  -87.4667     79.30
# 9        Mataura      NZ  2022-09-08 02:06:12 -46.1927  168.8643     50.49
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        94         100        5.99     overcast clouds
# 1        80          51        3.04       broken clouds
# 2        80          40       12.66    scattered clouds
# 3        70         100        3.44     overcast clouds
# 4        61          40       11.70    scattered clouds
# 5        81          75       11.50       broken clouds
# 6        50           9       10.45           clear sky
# 7        62          34        2.30    scattered clouds
# 8        84          31        4.18    scattered clouds
# 9        60          35        0.92    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
